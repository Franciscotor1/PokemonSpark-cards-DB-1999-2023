# %% [markdown]
# <a href="https://colab.research.google.com/github/Franciscotor1/PokemonSpark-cards-DB-1999-2023/blob/master/Pkemonesbd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Instala Java
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# Descarga e instala Apache Spark
# !wget -q https://archive.apache.org/dist/spark/spark-3.1.2/spark-3.1.2-bin-hadoop3.2.tgz
# !tar xf spark-3.1.2-bin-hadoop3.2.tgz
# !pip install -q findspark

# Configura las variables de entorno
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.1.2-bin-hadoop3.2"

# Añade Spark al sistema
import findspark
findspark.init()

# Crea una sesión Spark
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").appName("example").getOrCreate()

# %% [markdown]
# # Nueva sección

# %%
spark.version
# Out:
# '3.1.2'

# %%
# Instala e importa las bibliotecas necesarias
# !pip install pyspark
from pyspark.sql import SparkSession

# Inicia una sesión de Spark
spark = SparkSession.builder.appName("pokemon-analysis").getOrCreate()

# Lee el conjunto de datos desde el archivo CSV
file_path = "pokemondata-1999-2023.csv"  # Asegúrate de que el archivo esté en la misma ubicación que este script o proporciona la ruta completa
pokemon_df = spark.read.csv(file_path, header=True, inferSchema=True)

# Muestra el esquema del DataFrame
pokemon_df.printSchema()

# Muestra las primeras filas del DataFrame
pokemon_df.show(5)
# Out:
# Collecting pyspark
#   Downloading pyspark-3.5.0.tar.gz (316.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.9/316.9 MB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.5.0-py2.py3-none-any.whl size=317425345 sha256=ab79b218b320cb01634639452c433269978f4f27d9123b7a0c417eba3b60dfcb
#   Stored in directory: /root/.cache/pip/wheels/41/4e/10/c2cf2467f71c678cfc8a6b9ac9241e5e44a01940da8fbb17fc
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.5.0
# root
#  |-- id: string (nullable = true)
#  |-- set: string (nullable = true)
#  |-- series: string (nullable = true)
#  |-- publisher: string (nullable = true)
#  |-- generation: string (nullable = true)
#  |-- release_date: string (nullable = true)
#  |-- artist: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- set_num: string (nullable = true)
#  |-- types: string (nullable = true)
#  |-- supertype: string (nullable = true)
#  |-- subtypes: string (nullable = true)
#  |-- level: string (nullable = true)
#  |-- hp: integer (nullable = true)
#  |-- evolvesFrom: string (nullable = true)
#  |-- evolvesTo: string (nullable = true)
#  |-- abilities: string (nullable = true)
#  |-- attacks: string (nullable = true)
#  |-- weaknesses: string (nullable = true)
#  |-- retreatCost: string (nullable = true)
#  |-- convertedRetreatCost: string (nullable = true)
#  |-- rarity: string (nullable = true)
#  |-- flavorText: string (nullable = true)
#  |-- nationalPokedexNumbers: string (nullable = true)
#  |-- legalities: string (nullable = true)
#  |-- resistances: string (nullable = true)
#  |-- rules: string (nullable = true)
#  |-- regulationMark: string (nullable = true)
#  |-- ancientTrait: string (nullable = true)
#
# +-------+----+------+---------+----------+------------+---------------+---------+-------+-------------+---------+-----------+-----+---+-----------+------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------------------+--------------------+---------------+--------------------+--------------------+--------------------+
# |     id| set|series|publisher|generation|release_date|         artist|     name|set_num|        types|supertype|   subtypes|level| hp|evolvesFrom|   evolvesTo|           abilities|             attacks|          weaknesses|         retreatCost|convertedRetreatCost|              rarity|          flavorText|nationalPokedexNumbers|          legalities|    resistances|               rules|      regulationMark|        ancientTrait|
# +-------+----+------+---------+----------+------------+---------------+---------+-------+-------------+---------+-----------+-----+---+-----------+------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------------------+--------------------+---------------+--------------------+--------------------+--------------------+
# |base1-1|Base|  Base|     WOTC|     First|    1/9/1999|   Ken Sugimori| Alakazam|      1|  ['Psychic']|  Pokémon|['Stage 2']|   42| 80|    Kadabra|        null|"[{'name': 'Damag...| you may move 1 d...|            Confused|     or Paralyzed.""| 'type': 'Pokémon...|[{'name': 'Confus...|[{'type': 'Psychi...|  ['Colorless', 'Co...|                   3|      Rare Holo|Its brain can out...|                [65]|{'unlimited': 'Le...|
# |base1-2|Base|  Base|     WOTC|     First|    1/9/1999|   Ken Sugimori|Blastoise|      2|    ['Water']|  Pokémon|['Stage 2']|   52|100|  Wartortle|        null|"[{'name': 'Rain ...| you may attach 1...|            Confused|     or Paralyzed.""| 'type': 'Pokémon...|"[{'name': 'Hydro...|[{'type': 'Lightn...|  ['Colorless', 'Co...|                   3|      Rare Holo|A brutal Pokémon ...|                 [9]|{'unlimited': 'Le...|
# |base1-3|Base|  Base|     WOTC|     First|    1/9/1999|   Ken Sugimori|  Chansey|      3|['Colorless']|  Pokémon|  ['Basic']|   55|120|       null| ['Blissey']|                null|"[{'name': 'Scrun...| prevent all dama...| {'name': 'Double...| 'cost': ['Colorl...|         'Colorless'|         'Colorless'|          'Colorless']| 'convertedEnergy...| 'damage': '80'| 'text': 'Chansey...|[{'type': 'Fighti...|       ['Colorless']|
# |base1-4|Base|  Base|     WOTC|     First|    1/9/1999|Mitsuhiro Arita|Charizard|      4|     ['Fire']|  Pokémon|['Stage 2']|   76|120| Charmeleon|        null|"[{'name': 'Energ...| you may turn all...|            Confused|     or Paralyzed.""| 'type': 'Pokémon...|[{'name': 'Fire S...|[{'type': 'Water'...|  ['Colorless', 'Co...|                   3|      Rare Holo|Spits fire that i...|                 [6]|{'unlimited': 'Le...|
# |base1-5|Base|  Base|     WOTC|     First|    1/9/1999|   Ken Sugimori| Clefairy|      5|['Colorless']|  Pokémon|  ['Basic']|   14| 40|       null|['Clefable']|                null|"[{'name': 'Sing'...| such as discardi...| Clefairy's type ...|[{'type': 'Fighti...|       ['Colorless']|                   1|             Rare Holo|Its magical and c...|           [35]|{'unlimited': 'Le...|[{'type': 'Psychi...|                null|
# +-------+----+------+---------+----------+------------+---------------+---------+-------+-------------+---------+-----------+-----+---+-----------+------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------------------+--------------------+---------------+--------------------+--------------------+--------------------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import col

pokemon_count_by_generation = pokemon_df.groupBy("generation").count()
pokemon_count_by_generation.show()
# Out:
# +----------+-----+
# |generation|count|
# +----------+-----+
# |    Fourth| 1438|
# |   Seventh| 2973|
# |     First|  758|
# |    Eighth| 3665|
# |     Other|  157|
# |    Second| 1031|
# |   Fourth |  592|
# |     Ninth| 1304|
# |     Sixth| 1710|
# |     Fifth| 1653|
# |     Third| 1891|
# +----------+-----+

# %%
max_hp_pokemon = pokemon_df.orderBy(col("hp").desc()).first()
print("El Pokémon con la mayor cantidad de HP es:", max_hp_pokemon["name"], "con", max_hp_pokemon["hp"], "HP")
# Out:
# El Pokémon con la mayor cantidad de HP es: Eternatus VMAX con 340 HP

# %%
# Calcular el promedio de nivel por rareza DE POKEMON
avg_level_by_rarity = pokemon_df.groupBy("rarity").agg({"level": "avg"})
avg_level_by_rarity.show()
# Out:
# +--------------------+------------------+
# |              rarity|        avg(level)|
# +--------------------+------------------+
# | put Deoxys on to...|              null|
# |[{'name': 'Upward...|              null|
# | {'name': 'Thunde...|              37.0|
# | 'name': 'Super P...|              null|
# | 'type': 'Pokémon...|29.555555555555557|
# |          Rare Prime|              null|
# | {'name': 'Electr...|              null|
# | {'name': 'Combus...|              null|
# |[{'name': 'Chomp'...|              56.0|
# |"[{'name': 'Venge...|              null|
# | put Castform on ...|              35.0|
# | 'convertedEnergy...|              null|
# |  'cost': ['Psychic'|36.166666666666664|
# |   'cost': ['Grass']|              15.0|
# | {'name': 'Brutal...|              52.0|
# |"[{'name': 'Hydro...|              52.0|
# | done to Seaking....|              null|
# |[{'name': 'Poison...|              null|
# | or anything else...|              37.0|
# |['Colorless', 'Co...|43.333333333333336|
# +--------------------+------------------+
# only showing top 20 rows

# %%
# Filtrar Pokémon que tienen una habilidad específica
pokemon_with_ability = pokemon_df.filter(col("abilities").contains("your_specific_ability"))
pokemon_with_ability.show()
# Out:
# +---+---+------+---------+----------+------------+------+----+-------+-----+---------+--------+-----+---+-----------+---------+---------+-------+----------+-----------+--------------------+------+----------+----------------------+----------+-----------+-----+--------------+------------+
# | id|set|series|publisher|generation|release_date|artist|name|set_num|types|supertype|subtypes|level| hp|evolvesFrom|evolvesTo|abilities|attacks|weaknesses|retreatCost|convertedRetreatCost|rarity|flavorText|nationalPokedexNumbers|legalities|resistances|rules|regulationMark|ancientTrait|
# +---+---+------+---------+----------+------------+------+----+-------+-----+---------+--------+-----+---+-----------+---------+---------+-------+----------+-----------+--------------------+------+----------+----------------------+----------+-----------+-----+--------------+------------+
# +---+---+------+---------+----------+------------+------+----+-------+-----+---------+--------+-----+---+-----------+---------+---------+-------+----------+-----------+--------------------+------+----------+----------------------+----------+-----------+-----+--------------+------------+

# %%
# Imprimir la lista única de habilidades
unique_abilities = pokemon_df.select("abilities").distinct().collect()
for row in unique_abilities:
    print(row['abilities'])
# Out:
# "[{'name': 'Ripples', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Dark Healer', 'text': ""As long as Rocket's Snorlax ex has any Darkness Energy attached to it
# [{'name': 'Baby Evolution', 'text': 'Once during your turn (before your attack), you may put Jynx from your hand onto Smoochum (this counts as evolving Smoochum) and remove all damage counters from Smoochum.', 'type': 'Poké-Power'}]
# "[{'name': 'Bedhead', 'text': 'As long as Snorlax remains Asleep between turns, put 2 damage counters on 1 of the Defending Pokémon.', 'type': 'Poké-Body'}, {'name': 'Dozing', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Grass Whistle', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Magma Armor', 'text': ""Magcargo can't be Asleep or Paralyzed.""
# [{'name': 'Energy Refresh', 'text': 'As long as Leafeon is your Active Pokémon, whenever you attach an Energy card from your hand to 1 of your Pokémon, remove 2 damage counters from that Pokémon.', 'type': 'Poké-Body'}]
# "[{'name': 'Insight', 'text': ""If you have the same number of cards in your hand as your opponent
# [{'name': 'Curative Pollen', 'text': 'Once during your turn (before your attack), you may heal 20 damage from 1 of your Pokémon.', 'type': 'Ability'}]
# [{'name': 'Restoration', 'text': 'Once during your turn (before your attack), if this Pokémon is in your discard pile, you may put it onto your Bench. Then, attach a Darkness Energy card from your discard pile to this Pokémon.', 'type': 'Ability'}]
# "[{'name': 'Lazy', 'text': ""As long as this Pokémon is your Active Pokémon
# [{'name': 'Unit Color 2', 'text': 'As long as this Pokémon has Unit Energy LightningPsychicMetal attached to it, it is a Lightning, Psychic, and Metal Pokémon.', 'type': 'Ability'}]
# "[{'name': 'Loopy Lasso', 'text': ""Once during your turn
# [{'name': 'Zooming Draw', 'text': 'Once during your turn, you may put 1 damage counter on this Pokémon. If you do, draw a card.', 'type': 'Ability'}]
# [{'name': 'Gift', 'text': 'When you play Light Togetic from your hand, your opponent may search his or her deck for a Pokémon Tool card, show that card to you, and put it into his or her hand. Either way, you may do the same, and then each player who searched shuffles his or her deck.', 'type': 'Pokémon Power'}]
# "[{'name': 'Dark Moon', 'text': ""As long as Umbreon is your Active Pokémon and has a Darkness Energy attached to it
# "[{'name': 'Frenzy', 'text': ""As long as your opponent has Kyogre
# "[{'name': 'Levitate', 'text': ""If Vibrava has any basic Energy cards attached to it
# "[{'name': 'Clear Body', 'text': ""Regice can't be affected by any Special Conditions.""
# "[{'name': 'Install', 'text': ""As often as you like during your turn (before your attack)
# [{'name': 'Green Breath', 'text': 'When you attach a Grass Energy card from your hand to Sceptile, remove 2 damage counters from Sceptile.', 'type': 'Poké-Body'}]
# [{'name': 'Metal Eater', 'text': 'Once during your turn (before your attack), you may discard a Metal Pokémon from your hand. If you do, heal 100 damage from this Pokémon.', 'type': 'Ability'}]
# [{'name': 'Precognitive Aura', 'text': 'Once during your turn (before your attack), if you have Garchomp in play, you may search your deck for a card and put it into your hand. Then, shuffle your deck.', 'type': 'Ability'}]
# "[{'name': 'Fighting Instinct', 'text': ""This Pokémon's attacks cost Colorless less for each of your opponent's Pokémon V in play.""
# "[{'name': 'Mysterious Comet', 'text': ""Once during your turn
# [{'name': 'Extra Feather', 'text': 'Each of your Stage 2 Pokémon-ex does 10 more damage to the Defending Pokémon (before applying Weakness and Resistance).', 'type': 'Poké-Body'}]
# "[{'name': 'Root Protector', 'text': ""Any damage done to Swampert by attacks from your opponent's Pokémon that isn't an Evolved Pokémon is reduced by 20 (after applying Weakness and Resistance).""
# "[{'name': 'Bright Down', 'text': ""Prevent all effects of attacks
# "[{'name': 'Hyper Hypnosis', 'text': ""When you attach an Energy from your hand to this Pokémon
# [{'name': 'Air Mail', 'text': 'Once during your turn (before your attack), you may look at the top 2 cards of your deck and put 1 of them into your hand. Put the other card on the bottom of your deck.', 'type': 'Ability'}]
# "[{'name': 'Heat Boost', 'text': ""Once during your turn
# [{'name': 'Lay of the Land', 'text': 'If you have a Stadium in play, this Pokémon has no Retreat Cost.', 'type': 'Ability'}]
# "[{'name': 'Lucky Bonus', 'text': ""If you took this Pokémon as a face-down Prize card during your turn and your Bench isn't full
# "[{'name': 'Hydroelectric Power', 'text': ""You may make Floodlight do 10 more damage for each Water Energy attached to Lanturn
# "[{'name': 'Self-control', 'text': ""Golbat can't be Paralyzed.""
# "[{'name': 'Snappy Move', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Minus Charge', 'text': ""Once during your turn (before your attack)
# [{'name': 'Energy Burn', 'text': 'All Energy attached to Charizard are Fire Energy instead of their usual type.', 'type': 'Poké-Body'}]
# [{'name': 'RETURN', 'text': 'Once during your turn, when you put Unown from your hand onto your Bench, you may return all Energy attached to 1 of your Pokémon to your hand.', 'type': 'Poké-Power'}]
# "[{'name': 'Perfect Metal', 'text': ""Steelix can't be affected by any Special Conditions""
# [{'name': 'Weather Guard', 'text': 'Your Grass Pokémon have no Weakness.', 'type': 'Ability'}]
# "[{'name': 'Dragon Guard', 'text': ""Prevent all effects of your opponent's attacks
# "[{'name': 'Type Change', 'text': ""Once during your turn (before your attack)
# [{'name': 'Spongy Stone', 'text': 'At any times between turns, remove 1 damage counter from Root Fossil.', 'type': 'Poké-Body'}]
# "[{'name': 'Dark Genes', 'text': ""As long as Honchkrow has the Energy necessary to use its attack
# "[{'name': 'Fin Luster', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Plasma Steel', 'text': ""Prevent all damage done to your Metal Pokémon by attacks from your opponent's Pokémon-EX.""
# [{'name': 'Floating Shell', 'text': 'If you have a Stadium card in play, this Pokémon has no Retreat Cost.', 'type': 'Ability'}]
# [{'name': 'Fluffy Cotton', 'text': 'If any damage is done to this Pokémon by attacks, flip a coin. If heads, prevent that damage.', 'type': 'Ability'}]
# [{'name': 'Tar Generator', 'text': 'Once during your turn, you may attach a Fire Energy card, a Fighting Energy card, or 1 of each from your discard pile to your Pokémon in any way you like.', 'type': 'Ability'}]
# "[{'name': 'Trickery', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Fire Recharge', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Frenzy', 'text': ""As long as your opponent has Groudon
# "[{'name': 'Auxiliary Light', 'text': ""Once during your turn (before your attack)
# [{'name': 'Raging Roar', 'text': 'When you play this Pokémon from your hand to evolve 1 of your Pokémon, you may attach 1 Darkness Energy from your discard pile to this Pokémon for each Prize card your opponent has taken.', 'type': 'Ability'}]
# [{'name': 'Mystical Fire', 'text': 'Once during your turn (before your attack), you may draw cards until you have 6 cards in your hand.', 'type': 'Ability'}]
# [{'name': 'Blessings of the Frost', 'text': 'When you play this Pokémon from your hand to evolve 1 of your Pokémon during your turn, you may attach a Grass Energy card from your discard pile to 1 of your Pokémon.', 'type': 'Ability'}]
# "[{'name': 'Gale Shuriken', 'text': ""When you play this Pokémon from your hand to evolve 1 of your Pokémon during your turn
# "[{'name': 'Ultra Burst', 'text': ""This Pokémon can't attack unless your opponent has 2 or fewer Prize cards remaining.""
# [{'name': 'Primate Dexterity', 'text': 'If any damage is done to this Pokémon by attacks, flip a coin. If heads, prevent that damage.', 'type': 'Ability'}]
# [{'name': 'Explosiveness', 'text': 'If this Pokémon is in your hand when you are setting up to play, you may put it face down as your Active Pokémon.', 'type': 'Ability'}]
# "[{'name': 'Flee', 'text': ""If an attack does damage to Misty's Tentacruel while it's your Active Pokémon
# [{'name': 'Blissful Support', 'text': 'Once during your turn, when you play Blissey ex from your hand to evolve 1 of your Pokémon, you may discard all Energy cards attached to any number of your Pokémon and remove all damage counters from those Pokémon.', 'type': 'Poké-Power'}]
# "[{'name': 'Evolutionary Thunder', 'text': ""Once during your turn
# [{'name': 'JUNK', 'text': 'Once during your turn, when you put Unown J from your hand onto your Bench, you may flip a coin. If heads, search your discard pile for a Trainer card, show it to your opponent, and put it into your hand.', 'type': 'Poké-Power'}]
# "[{'name': 'Unearth', 'text': ""Once during your turn (before your attack)
# [{'name': 'Metal Links', 'text': 'Once during your turn (before your attack), you may attach a Metal Energy card from your discard pile to 1 of your Benched Pokémon.', 'type': 'Ability'}]
# [{'name': 'Strong Charge', 'text': 'Once during your turn (before your attack), you may search your deck for a Grass Energy card and a Lightning Energy card and attach them to your Pokémon in any way you like. Then, shuffle your deck.', 'type': 'Ability'}]
# "[{'name': 'Nine Temptations', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Prankish', 'text': ""When you play this Pokémon from your hand to evolve 1 of your Pokémon during your turn
# [{'name': 'Lunar Blessing', 'text': 'Once during your turn, if your Active Pokémon has any Psychic Energy attached, you may heal 20 damage from it, and it recovers from a Special Condition.', 'type': 'Ability'}]
# "[{'name': 'Fighting Fury Stance', 'text': ""Your Single Strike Pokémon's attacks do 30 more damage to your opponent's Active Pokémon (before applying Weakness and Resistance).""
# [{'type': 'Ability', 'name': 'Swelling Flash', 'text': 'Once during your turn, if this Pokémon is in your hand and you have more Prize cards remaining than your opponent, you may put this Pokémon onto your Bench.'}]
# "[{'name': 'Rain Dance', 'text': ""As often as you like during your turn (before your attack)
# "[{'name': 'Sleep Pendulum', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Fluff', 'text': ""Whenever Swablu would be damaged or affected by an opponent's attack and already has at least 1 damage counter on it
# "[{'name': 'Feathery', 'text': ""As long as Swablu is on your Bench
# "[{'name': 'Dense', 'text': ""Any damage done to Quagsire by attacks from your opponent's Evolved Pokémon is reduced by 20 (after applying Weakness and Resistance).""
# "[{'name': 'Silver Sparkle', 'text': ""If Lugia ex is your Active Pokémon and is damaged by an opponent's attack (even if Lugia ex is Knocked Out)
# "[{'name': 'Paranoid', 'text': ""As long as Machoke is Confused
# [{'name': 'Inferno Fandango', 'text': 'As often as you like during your turn (before your attack), you may attach a Fire Energy card from your hand to 1 of your Pokémon.', 'type': 'Ability'}]
# "[{'name': 'Iceberg Shield', 'text': ""If you have Regirock in play
# [{'name': 'Boss Pockets', 'text': 'This Pokémon may have up to 4 Pokémon Tools attached to it. If it loses this Ability, discard Pokémon Tools from it until only 1 remains.', 'type': 'Ability'}]
# [{'name': 'Restart', 'text': 'Once during your turn, you may draw cards until you have 3 cards in your hand.', 'type': 'Ability'}]
# "[{'name': 'Buzzap', 'text': ""At any time during your turn (before your attack)
# "[{'name': 'Shapeshift', 'text': ""Once during your turn (before your attack)
# [{'name': 'Retreat Aid', 'text': 'As long as Dodrio is on your Bench, you pay ColorlessColorless less to retreat your Active Pokémon (excluding Pokémon-ex and Baby Pokémon.)', 'type': 'Poké-Body'}]
# "[{'name': 'Trump Card', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Ectoplasm', 'text': ""If Dusknoir is your Active Pokémon and would be Knocked Out by damage from your opponent's attack
# [{'name': 'Rush In', 'text': 'Once during your turn (before your attack), if this Pokémon is on your Bench, you may switch this Pokémon with your Active Pokémon.', 'type': 'Ability'}]
# "[{'name': 'Ascension DNA', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Sol Shade', 'text': ""If you have Solrock in play
# "[{'name': 'Fossilized Memories', 'text': ""As long as this Pokémon is your Active Pokémon
# "[{'name': 'Lustrous Body', 'text': ""Prevent all effects of your opponent's Pokémon's Abilities done to this Pokémon.""
# "[{'name': 'Time Travel', 'text': ""If an opponent's attack would Knock Out Celebi
# [{'name': 'Prismatic Body', 'text': 'Each basic Energy card attached to Ditto provides every type of Energy but provides only 1 Energy at a time.', 'type': 'Poké-Body'}]
# "[{'name': 'Magic Odds', 'text': ""If Mr. Mime ex would be damaged by an attack
# "[{'name': 'Self-control', 'text': ""Zubat can't be Paralyzed.""
# "[{'name': 'Flash Fire', 'text': ""Once during your turn (before your attack)
# [{'name': 'Honeycomb Defender', 'text': 'If Scizor has 6 or more damage counters on it, any damage done to Scizor by attacks is reduced by 40 (after applying Weakness and Resistance).', 'type': 'Poké-Body'}]
# [{'name': 'Stealthy Body', 'text': 'If there is any Stadium card in play, this Pokémon has no Weakness.', 'type': 'Ability'}]
# "[{'name': 'Speed Cheer', 'text': ""The attacks of your Pokémon-GX in play that evolve from Eevee cost Colorless less. You can't apply more than 1 Speed Cheer Ability at a time.""
# "[{'name': 'Poisonous Puddle', 'text': ""Once during your turn
# "[{'name': 'Final Sting', 'text': ""Once during your turn (before your attack)
# [{'name': 'Dig Up', 'text': 'Once during your turn, when you play Quagsire from your hand to evolve 1 of your Pokémon, you may search your discard pile for up to 2 Pokémon Tool cards, show them to your opponent, and put them into your hand.', 'type': 'Poké-Power'}]
# "[{'name': 'Heat Metal', 'text': ""Your opponent can't remove the Special Condition Burned by evolving or devolving his or her Burned Pokémon. (This also includes putting a Pokémon Level-Up card onto the Burned Pokémon.) Whenever your opponent flips a coin for the Special Condition Burned between turns
# [{'name': 'Metallic Lift', 'text': 'If Metang has any Metal Energy attached to it, the Retreat Cost for Metang is 0.', 'type': 'Poké-Body'}]
# "[{'name': 'Sweet Veil', 'text': ""Each of your Pokémon that has any Fairy Energy attached to it can't be affected by any Special Conditions. (Remove any Special Conditions affecting those Pokémon.)""
# "[{'name': ""Light's End""
# "[{'name': 'Luminous Barrier', 'text': ""Prevent all effects of attacks
# "[{'name': 'Resistance Shade', 'text': ""If you have Lunatone in play
# [{'name': 'Greening Cells', 'text': 'Once during your turn, you may search your deck for a Grass Energy card and attach it to 1 of your Pokémon. Then, shuffle your deck. If you use this Ability, your turn ends.', 'type': 'Ability'}]
# "[{'name': 'Wave Veil', 'text': ""Prevent all damage done to your Benched Pokémon by attacks from your opponent's Pokémon.""
# "[{'name': 'Quaking Zone', 'text': ""As long as this Pokémon is in the Active Spot
# [{'name': '[Laugh]', 'text': 'Once during your turn (before your attack), you may flip a coin. If heads, each player shuffles his or her deck. This power can be used even if Unown [L] is Asleep, Confused, or Paralyzed.', 'type': 'Pokémon Power'}]
# [{'name': 'Bubble Turn', 'text': 'Once during your turn (before your attack), if Azumarill is on your Bench, you may flip a coin. If heads, return Azumarill and all cards attached to it to your hand.', 'type': 'Poké-Power'}]
# "[{'name': 'Magma Switch', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Strikes Back', 'text': ""If Rocket's Hitmonchan ex is your Active Pokémon and is damaged by an opponent's attack (even if Rocket's Hitmonchan ex is Knocked Out)
# "[{'name': 'Dangerous Scales', 'text': ""If Venomoth is your Active Pokémon and is damaged by an opponent's attack (even if Venomoth is Knocked Out)
# "[{'name': 'Energymite', 'text': ""Once during your turn (before your attack)
# [{'name': 'Deluge', 'text': 'As often as you like during your turn (before your attack), you may attach a Water Energy card from your hand to 1 of your Pokémon.', 'type': 'Ability'}]
# [{'name': 'Stellar Guidance', 'text': 'When you play this Pokémon from your hand onto your Bench, you may search your deck for a Supporter card, reveal it, and put it into your hand. Shuffle your deck afterward.', 'type': 'Ability'}]
# [{'name': 'Stance Change', 'text': 'Once during your turn (before your attack), you may switch this Pokémon with an Aegislash in your hand. (Any cards attached to this Pokémon, damage counters, Special Conditions, turns in play, and any other effects remain on the new Pokémon.)', 'type': 'Ability'}]
# "[{'name': 'Curative Bower', 'text': ""All of your Pokémon that have Grass Energy attached can't be Confused
# [{'name': 'Form Variation', 'text': 'Once during your turn (before your attack), you may search your discard pile for a Basic Pokémon (excluding Pokémon-ex and Ditto) and switch it with Ditto. (Any cards attached to Ditto, damage counters, Special Conditions, and effects on it are now on the new Pokémon.) Place Ditto in the discard pile.', 'type': 'Poké-Power'}]
# "[{'name': 'Reversal Aura', 'text': ""As long as you have more Prize cards left than your opponent
# [{'name': 'Baby Evolution', 'text': 'Once during your turn (before your attack), you may put Wobbuffet from your hand onto Wynaut (this counts as evolving Wynaut) and remove all damage counters from Wynaut.', 'type': 'Poké-Power'}]
# [{'name': 'Pump Up', 'text': 'If your opponent has 3 or less Prize cards left, Drifblim FB gets +40 HP.', 'type': 'Poké-Body'}]
# "[{'name': 'Healing Growth', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Sunny Heal', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Black Eyes', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Danger Perception', 'text': ""If this Pokémon's remaining HP is 100 or less
# [{'name': 'Firestarter', 'text': 'Once during your turn (before your attack), you may attach a Fire Energy card from your discard pile to 1 of your Benched Pokémon.', 'type': 'Ability'}]
# [{'type': 'Poké-Body', 'name': 'Versatile', 'text': 'Mew ex can use the attacks of all Pokémon in play as its own. (You still need the necessary Energy to use each attack.)'}]
# "[{'name': 'Primal Fortress', 'text': ""Your Pokémon take 30 less damage from attacks from your opponent's Pokémon V (after applying Weakness and Resistance).""
# "[{'name': 'Sand Damage', 'text': ""As long as Dark Tyranitar is your Active Pokémon
# [{'name': 'Flame Dash', 'text': 'Once during your turn, when you play Arcanine from your hand to evolve 1 of your Benched Pokémon, you may switch Arcanine with 1 of your Active Pokémon. If you do, you may move any number of Energy cards attached to that Pokémon to Arcanine.', 'type': 'Poké-Power'}]
# [{'name': 'Psychic Recharge', 'text': 'Once during your turn (before your attack), you may attach a Psychic Energy card from your discard pile to 1 of your Benched Pokémon.', 'type': 'Ability'}]
# [{'name': 'Thunderclap Zone', 'text': 'Each of your Pokémon that has any Lightning Energy attached to it has no Retreat Cost.', 'type': 'Ability'}]
# "[{'name': 'Almighty Evolution', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Forest Miasma', 'text': ""During Pokémon Checkup
# "[{'name': 'Matter Exchange', 'text': ""Once during your turn (before your attack)
# "[{'name': '[Increase]', 'text': ""When you play Unown [I] from your hand
# "[{'name': 'Dual Aura', 'text': ""As long as you have Latias or Latias ex in play
# [{'name': 'Mapping', 'text': 'Once during your turn, when you play Porygon2 from your hand to evolve 1 of your Pokémon, you may search your deck for a Stadium card, show it to your opponent, and put it into your hand. Shuffle your deck afterward.', 'type': 'Poké-Power'}]
# [{'name': 'Sunbeam', 'text': 'The maximum HP of each of your Lunatone in play is 130.', 'type': 'Ability'}]
# [{'name': 'Shell Armor', 'text': 'This Pokémon takes 30 less damage from attacks (after applying Weakness and Resistance).', 'type': 'Ability'}]
# "[{'name': 'More Poison', 'text': ""Put 2 more damage counters on your opponent's Poisoned Pokémon during Pokémon Checkup.""
# "[{'name': 'Gather Fire', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Temperamental Weather', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Knockout Gas', 'text': ""If Koffing is your Active Pokémon and is Knocked Out by an opponent's attack
# "[{'name': 'Clear Body', 'text': ""Metang can't be affected by any Special Conditions.""
# "[{'name': 'Protective Wall', 'text': ""Prevent all damage done to your Benched Pokémon by your opponent's attacks.""
# "[{'name': 'Energy Reaction', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Battle Rush', 'text': ""If your opponent has any Pokémon in play that has maximum HP of 120 or more
# "[{'name': 'Power Saver', 'text': ""If there are 4 or fewer Team Magma Pokémon in play
# [{'name': 'Goodnight, Babies', 'text': 'Once during your turn (before your attack), you may leave both Active Pokémon Asleep.', 'type': 'Ability'}]
# "[{'name': 'Hand Block', 'text': ""If you have a Stadium card in play
# "[{'name': 'Surprise Spores', 'text': ""During your opponent's turn
# [{'name': 'Energy Carnival', 'text': 'Once during your turn, you may attach a Basic Energy card from your hand to 1 of your Pokémon.', 'type': 'Ability'}]
# "[{'name': 'Carefree Countenance', 'text': ""As long as this Pokémon is on your Bench
# "[{'type': 'Ability', 'name': 'Poison Sacs', 'text': ""Your opponent's Poisoned Pokémon don't recover from that Special Condition when they evolve or devolve.""}]"
# "[{'name': 'Helical Swell', 'text': ""As long as this Pokémon is in the Active Spot
# [{'name': 'Lifeboat', 'text': 'Once during your turn, when you play this Pokémon from your hand to evolve 1 of your Pokémon, you may use this Ability. Each player puts a Basic Pokémon from their discard pile onto their Bench. (Your opponent puts a Basic Pokémon onto their Bench first.)', 'type': 'Ability'}]
# "[{'name': '[Perform]', 'text': ""If an attack damaged Unown [P] during your opponent's last turn and Unown [P] was your Active Pokémon
# "[{'name': 'Magnetic Flow', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Intimidating Armor', 'text': ""As long as Aggron ex is your Active Pokémon
# "[{'name': 'Primal Stare', 'text': ""As long as Kabutops is your Active Pokémon
# "[{'name': 'Craggy Face', 'text': ""As long as Glalie is your Active Pokémon
# [{'name': 'Metal Trait', 'text': 'As long as Bastiodon has a Pokémon Tool attached to it, remove 1 damage counter from Bastiodon between turns.', 'type': 'Poké-Body'}]
# "[{'name': 'Damage Switch', 'text': ""As often as you like during your turn (before your attack)
# "[{'name': 'Catastrophe', 'text': ""As long as Gengar is your Active Pokémon
# "[{'name': 'Magnetic Draw', 'text': ""Once during your turn (before your attack)
# [{'name': 'Floral Fragrance', 'text': 'Once during your turn (before your attack), you may search your deck for a Pokémon, reveal it, and put it into your hand. Shuffle your deck afterward.', 'type': 'Ability'}]
# "[{'name': 'Thorn Tempest', 'text': ""When you play this Pokémon from your hand to evolve 1 of your Pokémon
# [{'name': 'Explosive Fire Dance', 'text': 'When you play this Pokémon from your hand to evolve 1 of your Pokémon during your turn, you may look at the top 8 cards of your deck and attach any number of basic Energy cards you find there to your Pokémon in any way you like. Shuffle the other cards back into your deck.', 'type': 'Ability'}]
# [{'name': 'Dark Squall', 'text': 'As often as you like during your turn, you may attach a Darkness Energy card from your hand to 1 of your Pokémon.', 'type': 'Ability'}]
# "[{'name': 'Shadow Knife', 'text': ""When you play this Pokémon from your hand onto your Bench during your turn
# "[{'name': 'Strange Barrier', 'text': ""Whenever an attack by a Basic Pokémon (including your own) does 20 or more damage to Erika's Dratini (after applying Weakness and Resistance)
# [{'name': 'Baby Evolution', 'text': 'Once during your turn (before your attack), you may put Wobbuffet from your hand onto Wynaut (this counts as evolving Wynaut), and remove all damage counters from Wynaut.', 'type': 'Poké-Power'}]
# "[{'name': 'Empty Shell', 'text': ""When Shedinja is Knocked Out
# "[{'name': 'Night Vision', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Vigorous Aura', 'text': ""As long as Medicham is your Active Pokémon
# [{'name': 'Ocean Grow', 'text': 'Once during your turn, when you put Lugia LEGEND into play, you may look at the top 5 cards of your deck and attach all Energy cards you find there to Lugia LEGEND. Discard the other cards.', 'type': 'Poké-Power'}]
# [{'name': 'Gooey Regeneration', 'text': 'As often as you like during your turn (before your attack), you may discard an Energy attached to this Pokémon. If you do, heal 60 damage from this Pokémon.', 'type': 'Ability'}]
# [{'name': 'Energy Burn', 'text': 'All Energy attached to this Pokémon are Fire Energy instead of their usual type.', 'type': 'Ability'}]
# "[{'name': 'Lively Fruit', 'text': ""Prevent all effects of attacks from your opponent's Pokémon done to this Pokémon. (Damage is not an effect.)""
# [{'name': '[Metal]', 'text': 'Whenever a Metal Pokémon damages 1 of your Pokémon, reduce that damage by 30 (after applying Weakness and Resistance). This power stops working if you have more than 1 Unown [M] in play. (This power works even if Unown [M] is Asleep, Confused, or Paralyzed.)', 'type': 'Pokémon Power'}]
# [{'name': 'Toxic Gas', 'text': 'Ignore all Pokémon Powers other than Toxic Gases. This power stops working while Muk is affected by a Special Condition.', 'type': 'Pokémon Power'}]
# "[{'name': 'Lonesome', 'text': ""As long as you have less Pokémon in play than your opponent
# "[{'name': 'Burning Coat', 'text': ""Whenever 1 of your opponent's Pokémon is Knocked Out by damage from Entei's attacks
# "[{'name': 'Wash Out', 'text': ""As often as you like during your turn (before your attack)
# "[{'name': 'Toxic Spikes', 'text': ""Whenever your opponent's Active Pokémon retreats
# "[{'name': 'Bench Barrier', 'text': ""Prevent all damage done to your Benched Pokémon by your opponent's attacks.""
# [{'name': 'Go for a Swim', 'text': 'Once during your turn (before your attack), you may look at the top 2 cards of your deck and put them back in any order.', 'type': 'Ability'}]
# "[{'name': 'Cat Walk', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Tag Coach', 'text': ""Your TAG TEAM Pokémon take 20 less damage from your opponent's attacks (after applying Weakness and Resistance).""
# [{'name': 'Shadow Connection', 'text': 'As often as you like during your turn (before your attack), you may move a basic Darkness Energy from 1 of your Pokémon to another of your Pokémon.', 'type': 'Ability'}]
# "[{'name': 'Jamming Attachment', 'text': ""When you play this Pokémon from your hand to evolve 1 of your Pokémon during your turn
# "[{'name': 'Block Dust', 'text': ""As long as Vileplume ex is your Active Pokémon
# [{'name': 'Fiery Aura', 'text': 'As long as Rapidash is your Active Pokémon, put 4 damage counters instead of 2 on Burned Pokémon between turns.', 'type': 'Poké-Body'}]
# [{'name': 'GUARD', 'text': 'Once during your turn (before your attack), if Unown G is on your Bench, you may discard all cards attached to Unown G and attach Unown G to 1 of your Pokémon as a Pokémon Tool card. As long as Unown G is attached to a Pokémon, prevent all effects of attacks, excluding damage, done to that Pokémon.', 'type': 'Poké-Power'}]
# "[{'name': 'Revenge Fang', 'text': ""If you have less Benched Pokémon than your opponent
# "[{'name': 'Sunny Day', 'text': ""Each of your Grass Pokémon's and Fire Pokémon's attacks does 10 more damage to the Defending Pokémon (before applying Weakness and Resistance).""
# "[{'name': 'Overgrow', 'text': ""If this Pokémon's remaining HP is 50 or less
# [{'name': 'Flight Support', 'text': 'Your Latios in play have no Retreat Cost.', 'type': 'Ability'}]
# [{'name': 'Pupate', 'text': 'Once during your turn (before your attack), you may flip a coin. If heads, search your deck for a card that evolves from this Pokémon and put it onto this Pokémon to evolve it. Then, shuffle your deck.', 'type': 'Ability'}]
# "[{'name': 'Crystal Veil', 'text': ""Prevent all damage done to this Pokémon by attacks from your opponent's Pokémon VMAX
# "[{'name': 'Ancient Wind', 'text': ""Once during your turn (before your attack)
# [{'name': 'Exoskeleton', 'text': 'All damage done by attacks to Forretress is reduced by 10 (after applying Weakness and Resistance).', 'type': 'Poké-Body'}]
# [{'name': 'Rain Dish', 'text': 'At any time between turns, remove 1 damage counter from Ludicolo.', 'type': 'Poké-Body'}]
# [{'name': 'Baby Evolution', 'text': 'Once during your turn (before your attack), you may put Sudowoodo from your hand onto Bonsly (this counts as evolving Bonsly) and remove all damage counters from Bonsly.', 'type': 'Poké-Power'}]
# "[{'name': 'Telepass', 'text': ""Once during your turn (before your attack)
# [{'name': 'Trash Cloak', 'text': 'If Wormadam Trash Cloak has a Pokémon Tool card attached to it, any damage done to Wormadam Trash Cloak by attacks is reduced by 20 (after applying Weakness and Resistance).', 'type': 'Poké-Body'}]
# "[{'name': 'Sheet Lightning', 'text': ""Once during your turn
# "[{'name': 'Inner Focus', 'text': ""Riolu can't be Paralyzed.""
# "[{'name': 'Underwater Dive', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Sap Sipper', 'text': ""This Pokémon's attacks do 40 more damage to your opponent's Grass Pokémon (before applying Weakness and Resistance).""
# [{'name': 'Breath of the Leaves', 'text': 'If this Pokémon is your Active Pokémon, once during your turn (before your attack), you may heal 50 damage from 1 of your Pokémon that has any Energy attached to it.', 'type': 'Ability'}]
# [{'name': 'Mantine Surf', 'text': 'If this Pokémon has any Energy attached to it, it has no Retreat Cost.', 'type': 'Ability'}]
# [{'name': 'Resetting Hole', 'text': 'Once during your turn (before your attack), if this Pokémon is on your Bench, you may discard any Stadium card in play. If you do, discard this Pokémon and all cards attached to it.', 'type': 'Ability'}]
# "[{'name': 'Shadow Box', 'text': ""Pokémon-GX that have any damage counters on them (both yours and your opponent's) have no Abilities.""
# "[{'name': 'Stand Sentry', 'text': ""Basic Energy attached to your Benched Pokémon can't be discarded by an effect of your opponent's Item or Supporter cards.""
# [{'type': 'Ability', 'name': 'Insta-Flock', 'text': 'When you play this Pokémon from your hand onto your Bench during your turn, you may search your deck for up to 3 Flamigo, reveal them, and put them into your hand. Then, shuffle your deck.'}]
# "[{'name': 'Soothing Aroma', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Lolling About', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Primal Veil', 'text': ""As long as Armaldo is your Active Pokémon
# [{'name': 'Power Pinchers', 'text': 'As long as Crawdaunt is your Active Pokémon, when any of your Active Pokémon does damage to the Defending Pokémon, the attack does 10 more damage (before applying Weakness and Resistance).', 'type': 'Poké-Body'}]
# "[{'name': 'Golden Wing', 'text': ""If Ho-Oh ex would be Knocked Out by damage from an opponent's attack
# "[{'name': 'Duplicate', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Primal Light', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Time Travel', 'text': ""If Celebi Star would be Knocked Out by damage from an opponent's attack
# "[{'name': 'Gleam Eyes', 'text': ""Once during your turn
# "[{'name': 'Miracle Oracle', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Mischievous Fang', 'text': ""When you play this Pokémon from your hand onto your Bench
# [{'name': 'Wondrous Gift', 'text': 'Once during your turn (before your attack), you may flip a coin. If heads, put an Item card from your discard pile on top of your deck.', 'type': 'Ability'}]
# [{'name': 'Conductive Body', 'text': 'As long as this Pokémon is your Active Pokémon, its Retreat Cost is Colorless less for each Beldum on your Bench.', 'type': 'Ability'}]
# "[{'name': 'Power Bind', 'text': ""If you have 4 or fewer Pokémon in play
# [{'name': 'Tag Transport', 'text': 'Once during your turn (before your attack), you may switch your Active TAG TEAM Pokémon with 1 of your Benched Pokémon.', 'type': 'Ability'}]
# [{'name': 'Sturdy Shield', 'text': 'This Pokémon takes 20 less damage from attacks (after applying Weakness and Resistance).', 'type': 'Ability'}]
# "[{'name': 'Counterattack', 'text': ""If this Pokémon is in the Active Spot and is damaged by an attack from your opponent's Pokémon (even if this Pokémon is Knocked Out)
# "[{'name': 'Gift Exchange', 'text': ""Once during your turn (before your attack)
# [{'name': 'Delta Transport', 'text': 'Once during your turn (before your attack), if Pelipper is on your Bench, you may switch 1 of your Active Pokémon that has δ on its card with 1 of your Benched Pokémon.', 'type': 'Poké-Power'}]
# "[{'name': 'Forest Murmurs', 'text': ""Once during your turn (before your attack)
# [{'name': 'Aqua Skin', 'text': 'When you attach a Water Energy card from your hand to Manaphy, remove 2 damage counters from Manaphy.', 'type': 'Poké-Body'}]
# [{'name': 'Fair-Weather Heal', 'text': 'Once during your turn (before your attack), you may heal 20 damage from 1 of your Pokémon that has any Grass Energy attached to it.', 'type': 'Ability'}]
# "[{'name': 'Slip Trip', 'text': ""Each player can't attach any Pokémon Tool cards from his or her hand to any of his or her Pokémon.""
# "[{'name': 'Antibodies', 'text': ""This Pokémon can't be affected by any Special Conditions. (Remove any Special Conditions affecting this Pokémon.)""
# "[{'name': 'More Poison', 'text': ""Put 1 more damage counter on your opponent's Poisoned Pokémon between turns.""
# [{'name': 'Excitable Draw', 'text': 'Once during your turn (before your attack), you may flip a coin. If heads, shuffle your hand into your deck and then draw 6 cards. If you use this Ability, your turn ends.', 'type': 'Ability'}]
# "[{'name': 'Flaming Shot', 'text': ""Once during your turn (before your attack)
# [{'name': 'Happy Match', 'text': 'When you play this Pokémon from your hand onto your Bench during your turn, you may put a Supporter card from your discard pile into your hand.', 'type': 'Ability'}]
# [{'name': 'Lucky Match', 'text': 'When you play this Pokémon from your hand onto your Bench during your turn, you may flip a coin. If heads, put a Supporter card from your discard pile into your hand.', 'type': 'Ability'}]
# [{'name': 'Solar Evolution', 'text': 'When you attach an Energy card from your hand to this Pokémon during your turn, you may search your deck for a card that evolves from this Pokémon and put it onto this Pokémon to evolve it. Then, shuffle your deck.', 'type': 'Ability'}]
# "[{'name': 'Pure Body', 'text': ""Whenever you attach a Water Energy card from your hand to Suicune
# "[{'name': 'Chain of Events', 'text': ""As long as Plusle is your Active Pokémon
# "[{'name': 'Electro Recycle', 'text': ""Once during your turn (before your attack)
# [{'name': 'Evolutionary Toxic', 'text': 'Once during your turn, when you play Crobat from your hand to evolve 1 of your Pokémon, you may choose 1 of the Defending Pokémon. That Pokémon is now Poisoned. Put 2 damage counters instead of 1 on that Pokémon between turns.', 'type': 'Poké-Power'}]
# [{'name': 'Cottonweed', 'text': 'If Hoppip has any Grass Energy attached to it, the Retreat Cost for Hoppip is 0.', 'type': 'Poké-Body'}]
# "[{'name': 'Cosmic Power', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Metal Chain', 'text': ""Once during your turn (before your attack)
# [{'name': 'Nuzzly Gathering', 'text': 'Once during your turn (before your attack), you may search your deck for a Pokémon that has the Nuzzle attack, reveal it, and put it into your hand. Then, shuffle your deck.', 'type': 'Ability'}]
# "[{'name': 'Cursed Message', 'text': ""If this Pokémon is Knocked Out by damage from an attack from your opponent's Pokémon
# "[{'type': 'Ability', 'name': 'Big Roar', 'text': ""Once during your turn
# "[{'name': 'Jagged Stone', 'text': ""If Claw Fossil is your Active Pokémon and is damaged by an opponent's attack (even if Claw Fossil is Knocked Out)
# [{'name': 'Legendary Ascent', 'text': 'Once during your turn, when you put Zapdos ex from your hand onto your Bench, you may switch 1 of your Active Pokémon with Zapdos ex. If you do, you may also move any number of basic Lightning Energy cards attached to your Pokémon to Zapdos ex.', 'type': 'Poké-Power'}]
# "[{'name': 'Reactive Recharge', 'text': ""If Magneton would be Knocked Out by damage from an opponent's attack
# "[{'name': 'Thunder Rumble', 'text': ""Once during your turn (before your attack)
# [{'name': 'Toxic Virus', 'text': 'At any time between turns, each player puts 1 more damage counter on his or her Poisoned Pokémon.', 'type': 'Poké-Body'}]
# "[{'name': 'Bad Sleeping Habits', 'text': ""As long as Snorlax is Asleep
# [{'name': 'Energy Connect', 'text': 'As often as you like during your turn (before your attack), you may move a basic Energy attached to 1 of your Benched Pokémon to your Active Pokémon.', 'type': 'Ability'}]
# [{'name': 'Sinister Selection', 'text': 'Once during your turn (before your attack), you may look at the top 2 cards of your deck and put 1 of them into your hand. Discard the other card.', 'type': 'Ability'}]
# "[{'name': 'Poison Enzyme', 'text': ""Prevent all damage done to this Pokémon by attacks from your opponent's Poisoned Pokémon.""
# "[{'name': 'Wish Upon a Star', 'text': ""If you took this Pokémon as a face-down Prize card during your turn and your Bench isn't full
# [{'name': 'Call Signal', 'text': 'Once during your turn (before your attack), you may search your deck for up to 3 Supporter cards, reveal them, and put them into your hand. Then, shuffle your deck. If you searched your deck in this way, this Pokémon is Knocked Out.', 'type': 'Ability'}]
# "[{'name': 'Hazard Sensor', 'text': ""If this Pokémon is in the Active Spot and is damaged by an attack from your opponent's Pokémon (even if this Pokémon is Knocked Out)
# "[{'type': 'Ability', 'name': 'Read the Stars', 'text': ""Once during your turn
# "[{'type': 'Ability', 'name': 'Cursed Land', 'text': ""As long as this Pokémon is in the Active Spot
# "[{'name': 'Pollen Stench', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Psymimic', 'text': ""Once during your turn
# "[{'name': 'Call for Help', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Energetic Impulse', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Attracting Body', 'text': ""If Delcatty is your Active Pokémon and is damaged by an opponent's attack (even if Delcatty is Knocked Out)
# [{'name': 'Unaware', 'text': 'Prevent all effects of attacks, excluding damage, done to Bibarel.', 'type': 'Poké-Body'}]
# "[{'name': 'Radiance', 'text': ""If Electrode is your Active Pokémon and is damaged by an opponent's attack (even if Electrode is Knocked Out)
# "[{'name': 'Dragon Intimidation', 'text': ""If Garchomp is your Active Pokémon and is damaged by an opponent's attack (even if Garchomp is Knocked Out)
# [{'name': 'Sweet Sleeping Face', 'text': 'As long as Cleffa is Asleep, prevent all damage done to Cleffa by attacks.', 'type': 'Poké-Body'}]
# "[{'name': 'Magical Trans', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Allergy Panic', 'text': ""Apply Weakness for each Pokémon (both yours and your opponent's) as ×4 instead.""
# "[{'name': 'Incandescent Body', 'text': ""If this Pokémon is your Active Pokémon and is damaged by an opponent's attack (even if this Pokémon is Knocked Out)
# "[{'name': 'Apple Drop', 'text': ""Once during your turn
# "[{'name': 'Screen Cleaner', 'text': ""Prevent all effects of your opponent's attacks
# "[{'name': 'Fillet Memento', 'text': ""If this Pokémon is in the Active Spot and is Knocked Out by damage from an attack from your opponent's Pokémon
# "[{'name': 'Glaring Gaze', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Dark Protection', 'text': ""Any damage done to Crawdaunt by your opponent's attacks is reduced by 10 for each Darkness Energy attached to Crawdaunt (after applying Weakness and Resistance). You can't reduce more than 20 damage in this way.""
# [{'name': 'Dual Armor', 'text': 'As long as Magcargo has any Fighting Energy attached to it, Magcargo is both Fire and Fighting type.', 'type': 'Poké-Body'}]
# [{'name': 'Delta Reactor', 'text': 'As long as any Stadium card with Holon in its name is in play, each of your Pokémon that has δ on its card does 10 more damage to the Defending Pokémon (before applying Weakness and Resistance).', 'type': 'Poké-Body'}]
# [{'name': 'Intuition', 'text': 'When you play this Pokémon from your hand to evolve 1 of your Pokémon, you may draw 2 cards.', 'type': 'Ability'}]
# [{'name': 'Dark Trance', 'text': 'As often as you like during your turn (before your attack), you may move a Darkness Energy attached to 1 of your Pokémon to another of your Pokémon.', 'type': 'Ability'}]
# "[{'name': 'Block', 'text': ""As long as this Pokémon is your Active Pokémon
# "[{'name': 'Ice Shield', 'text': ""Any damage done by an opponent's attack to each of your Water Pokémon that has any Water Energy attached to it is reduced by 20 (after applying Weakness and Resistance).""
# "[{'name': 'Magic Evens', 'text': ""Prevent all damage done to this Pokémon by your opponent's attacks if that damage is exactly 20
# "[{'name': 'Last Pattern', 'text': ""If this Pokémon is Knocked Out by damage from an opponent's attack
# [{'name': 'Intrepid Sword', 'text': 'Once during your turn, you may look at the top 3 cards of your deck and attach any number of Metal Energy cards you find there to this Pokémon. Put the other cards into your hand. If you use this Ability, your turn ends.', 'type': 'Ability'}]
# "[{'name': 'Top Entry', 'text': ""Once during your turn
# [{'name': 'Buzzap Generator', 'text': 'Once during your turn, if this Pokémon is on your Bench, you may search your deck for up to 2 Lightning Energy cards and attach them to your Lightning Pokémon in any way you like. Then, shuffle your deck. If you searched your deck in this way, this Pokémon is Knocked Out.', 'type': 'Ability'}]
# "[{'name': 'Ear Moves', 'text': ""Once during your turn
# "[{'name': 'Poison Peak', 'text': ""During Pokémon Checkup
# "[{'type': 'Ability', 'name': 'Well-Baked Body', 'text': ""This Pokémon can't be Burned. Prevent all damage done to this Pokémon by attacks from your opponent's Fire Pokémon.""}]"
# [{'name': 'Sticky Goo', 'text': 'As long as Dark Muk is your Active Pokémon, your opponent pays ColorlessColorless more to retreat his or her Active Pokémon.', 'type': 'Poké-Body'}]
# "[{'name': 'Delta Support', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Extra Liquid', 'text': ""Each player's Pokémon-ex can't use any Poké-Powers and pays Colorless more Energy to use its attacks. Each Pokémon can't be affected by more than 1 Extra Liquid Poké-Body.""
# [{'name': 'HEAL', 'text': 'Once during your turn (before your attack), if you have Unown H, Unown E, Unown A, and Unown L on your Bench, you may remove all Special Conditions from 1 of your Active Pokémon.', 'type': 'Poké-Power'}]
# [{'name': 'Thick Fat', 'text': 'Any damage done to Dewgong by attacks from Fire Pokémon and Water Pokémon is reduced by 30 (after applying Weakness and Resistance).', 'type': 'Poké-Body'}]
# "[{'name': 'Ruler of the Night', 'text': ""As long as this Pokémon is your Active Pokémon
# [{'name': 'Sunny Bloom', 'text': 'Once at the end of your turn (after your attack), you may use this Ability. Draw cards until you have 4 cards in your hand.', 'type': 'Ability'}]
# "[{'name': 'Elder Tree Barrier', 'text': ""If this Pokémon is Knocked Out by damage from an attack from your opponent's Pokémon V
# "[{'name': 'Restless Sleep', 'text': ""If your opponent's attack does damage to Rocket's Snorlax and Rocket's Snorlax is already Asleep (even if it's Knocked Out)
# "[{'name': 'Slippery Skin', 'text': ""As long as the Defending Pokémon is an Evolved Pokémon
# "[{'name': 'Healing Aroma', 'text': ""As long as Meganium is your Active Pokémon
# "[{'name': 'Devo Flash', 'text': ""Once during your turn
# "[{'name': 'Danger Perception', 'text': ""As long as Scizor ex's remaining HP is 60 or less
# "[{'name': 'Extra Noise', 'text': ""As long as Exploud ex is your Active Pokémon
# "[{'name': 'Good Night Melody', 'text': ""Once during your turn (before your attack)
# [{'name': 'Exoskeleton', 'text': 'Any damage done to Kakuna by attacks is reduced by 20 (after applying Weakness and Resistance).', 'type': 'Poké-Body'}]
# "[{'name': 'Retreat Aid', 'text': ""As long as this Pokémon is on your Bench
# [{'name': 'Memories of Dawn', 'text': 'This Pokémon can use the attacks of any of your Basic Pokémon in play. (You still need the necessary Energy to use each attack.)', 'type': 'Ability'}]
# [{'name': 'Evolutionary Advantage', 'text': 'If you go second, this Pokémon can evolve during your first turn.', 'type': 'Ability'}]
# "[{'name': 'Unseen Flash', 'text': ""Once during your turn (before your attack)
# [{'name': 'Electric Swamp', 'text': 'Once during your turn (before your attack), if this Pokémon is in your hand and you have at least 4 Lightning Energy cards in play, you may play this Pokémon onto your Bench. If you do, move any number of Lightning Energy from your other Pokémon to this Pokémon.', 'type': 'Ability'}]
# [{'name': 'Pumpkin Pit', 'text': 'When you play this Pokémon from your hand onto your Bench during your turn, you may discard a Stadium in play.', 'type': 'Ability'}]
# "[{'name': 'Bouquet Magic', 'text': ""You must discard a Basic Grass Energy card from your hand in order to use this Ability. Once during your turn
# "[{'name': '[Chase]', 'text': ""As long as Unown [C] is your Active Pokémon
# "[{'name': 'Deadlock', 'text': ""As long as Dunsparce is your Active Pokémon
# "[{'name': 'Moonlight Veil', 'text': ""Each of your Pokémon that evolves from Eevee has no Weakness
# "[{'name': 'Heat Shift', 'text': ""Once during your turn (before your attack)
# [{'name': 'Big Wing', 'text': 'Once during your turn (before your attack), if this Pokémon is your Active Pokémon, you may have your opponent switch his or her Active Pokémon with 1 of his or her Benched Pokémon.', 'type': 'Ability'}]
# [{'name': 'Sand Flap', 'text': 'Once during your turn (before your attack), you may choose either player. That player shuffles his or her hand into his or her deck and draws 4 cards.', 'type': 'Ability'}]
# "[{'name': 'Roadblock', 'text': ""Your opponent can't have more than 4 Benched Pokémon. If they have 5 or more Benched Pokémon
# [{'name': 'Metal Transfer', 'text': 'As often as you like during your turn, you may move a Metal Energy from 1 of your Pokémon to another of your Pokémon.', 'type': 'Ability'}]
# [{'name': 'Infiltrator', 'text': 'If any damage is done to this Pokémon by attacks, flip a coin. If heads, prevent that damage.', 'type': 'Ability'}]
# "[{'name': 'Wild Style', 'text': ""This Pokémon's attacks cost Colorless less for each of your opponent's Single Strike
# [{'name': 'Exoskeleton', 'text': 'All damage by attacks to Kakuna is reduced by 10 (after applying Weakness and Resistance).', 'type': 'Poké-Body'}]
# "[{'name': 'Nectar Pod', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Hard Amber', 'text': ""As long as Old Amber is on your Bench
# ...
# "[{'name': 'Delta Aura', 'text': ""If you have Latias or Latias ex in play
# "[{'name': 'Wild Guard', 'text': ""Prevent all effects of attacks
# [{'name': 'Shortcut', 'text': 'The Retreat Cost for each Porygon, Porygon2, and Porygon-Z you have in play is Colorless less.', 'type': 'Poké-Body'}]
# "[{'name': 'Drag Along', 'text': ""If this Pokémon is your Active Pokémon and is Knocked Out by damage from an opponent's attack
# "[{'name': ""King's Palace""
# "[{'name': 'Tyrannical Heart', 'text': ""As long as you don't have more Pokémon in play than your opponent
# [{'name': 'Darkness Guard', 'text': 'If this Pokémon has any Darkness Energy attached, it takes 20 less damage from attacks (after applying Weakness and Resistance).', 'type': 'Ability'}]
# "[{'name': 'Shining Horn', 'text': ""As long as Skarmory is the only Pokémon you have in play
# [{'name': 'BOUNCE', 'text': 'Once during your turn (before your attack), if Unown B is on your Bench, you may flip a coin. If heads, discard all cards attached to any 1 of your Unown and shuffle that Pokémon back into your deck.', 'type': 'Poké-Power'}]
# "[{'name': 'Primal Shell', 'text': ""As long as Kabutops is your Active Pokémon
# "[{'name': 'Time Crystal', 'text': ""Each Pokémon (both yours and your opponent's) (excluding Pokémon SP) can't use any Poké-Bodies.""
# "[{'name': 'Wind Erosion', 'text': ""As long as Flygon is your Active Pokémon
# [{'name': 'Plunge', 'text': 'Once during your turn (before your attack), if Marshtomp is on your Bench, you may flip a coin. If heads, move all Energy cards attached to your Active Pokémon to Marshtomp. If you do, switch Marshtomp with that Active Pokémon.', 'type': 'Poké-Power'}]
# [{'name': 'Bust In', 'text': 'When you play this Pokémon from your hand onto your Bench, you may move any number of basic Energy attached to your Pokémon to this Pokémon. If you do, switch this Pokémon with your Active Pokémon.', 'type': 'Ability'}]
# [{'name': 'Gathering of Cats', 'text': 'Ignore all Energy in the attack costs of each of your Pokémon in play that has the Caturday attack.', 'type': 'Ability'}]
# [{'name': 'Plunge', 'text': 'Once during your turn (before your attack), if this Pokémon is on your Bench, you may move all Energy from your Active Pokémon to this Pokémon. If you do, switch it with your Active Pokémon.', 'type': 'Ability'}]
# [{'name': 'Seething Currents', 'text': 'Once during your turn, you may have either player shuffle their hand and put it on the bottom of their deck. If that player put any cards on the bottom of their deck in this way, they draw 4 cards.', 'type': 'Ability'}]
# [{'name': 'Flare Float', 'text': 'If this Pokémon has any Fire Energy attached, it has no Retreat Cost.', 'type': 'Ability'}]
# "[{'name': 'Stellar Veil', 'text': ""Prevent all damage counters from being placed on your Benched Pokémon by effects of attacks used by your opponent's Basic Pokémon.""
# "[{'name': 'Downpour', 'text': ""As often as you like during your turn (before your attack)
# [{'name': 'Power Gene', 'text': 'As long as Nidoking is in play, your attacks by Nidoran ♀, Nidorina, Nidoqueen, Nidoran ♂, and Nidorino do 10 more damage to the Defending Pokémon.', 'type': 'Poké-Body'}]
# "[{'name': 'Stages of Evolution', 'text': ""As long as Hitmontop is an Evolved Pokémon
# "[{'name': 'Skull Stone', 'text': ""During your opponent's turn
# "[{'name': 'Pot Shell', 'text': ""Prevent all effects of attacks
# "[{'name': 'Extreme Speed', 'text': ""Arcanine G's Retreat Cost is Colorless less for each Fire Energy attached to Arcanine G.""
# "[{'name': 'Marvel Shell', 'text': ""Prevent all effects of attacks
# "[{'name': 'Bright Look', 'text': ""When you play this Pokémon from your hand to evolve 1 of your Pokémon
# [{'name': 'Sturdy', 'text': 'If this Pokémon has full HP and would be Knocked Out by damage from an attack, this Pokémon is not Knocked Out and its remaining HP becomes 10 instead.', 'type': 'Ability'}]
# "[{'name': 'Flare Command', 'text': ""Once during your turn (before your attack)
# [{'name': 'Energy Reload', 'text': 'Once during your turn (before your attack), you may move a Grass Energy from 1 of your other Pokémon to this Pokémon.', 'type': 'Ability'}]
# "[{'name': 'Rapid-Fire Poison', 'text': ""Once during your turn
# "[{'name': 'Star of Fortune', 'text': ""During your turn
# "[{'name': 'Final Wish', 'text': ""When this Pokémon is Knocked Out by damage from an opponent's attack
# [{'name': 'Energy Evolution', 'text': 'When you attach a basic Energy card from your hand to this Pokémon, you may search your deck for a card that evolves from this Pokémon that is the same type as that Energy card and put it onto this Pokémon. (This counts as evolving this Pokémon.) Shuffle your deck afterward.', 'type': 'Ability'}]
# [{'name': 'Bright Heal', 'text': 'Once during your turn (before your attack), you may heal 20 damage from each of your Pokémon.', 'type': 'Ability'}]
# [{'name': 'Psychic Transfer', 'text': 'As often as you like during your turn (before your attack), you may move a Psychic Energy from 1 of your Pokémon to another of your Pokémon.', 'type': 'Ability'}]
# [{'name': 'Hydrating Drops', 'text': 'Once during your turn (before your attack), you may heal 30 damage from your Active Water Pokémon.', 'type': 'Ability'}]
# [{'name': 'Roaring Resolve', 'text': 'Once during your turn, you may put 2 damage counters on this Pokémon. If you do, search your deck for a Fighting Energy card and attach it to this Pokémon. Then, shuffle your deck.', 'type': 'Ability'}]
# "[{'name': 'Limber', 'text': ""This Pokémon can't be Paralyzed.""
# "[{'name': 'Mysterious Nest', 'text': ""Colorless Pokémon in play (both yours and your opponent's) have no Weakness.""
# [{'name': 'Voltaic Float', 'text': 'If this Pokémon has any Lightning Energy attached, it has no Retreat Cost.', 'type': 'Ability'}]
# [{'type': 'Ability', 'name': 'Strange Behavior', 'text': 'As often as you like during your turn, you may move 1 damage counter from 1 of your other Pokémon to this Pokémon.'}]
# [{'type': 'Ability', 'name': 'Dino Cry', 'text': 'Once during your turn, you may attach up to 2 Basic Fighting Energy cards from your discard pile to your Basic Fighting Pokémon in any way you like. If you use this Ability, your turn ends.'}]
# [{'name': 'Retreat Aid', 'text': 'As long as Dodrio is Benched, pay Colorless less to retreat your Active Pokémon.', 'type': 'Pokémon Power'}]
# "[{'name': 'Super Dynamo', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Poison Resistance', 'text': ""Scizor can't be Poisoned.""
# "[{'name': 'Burning Aura', 'text': ""As long as Typhlosion is your Active Pokémon
# "[{'name': 'Irritating Buzz', 'text': ""As long as Flygon is your Active Pokémon
# [{'name': 'Adaptive Evolution', 'text': 'This Pokémon can evolve during your first turn or the turn you play it.', 'type': 'Ability'}]
# "[{'name': 'Shining Spirit', 'text': ""Damage from this Pokémon's attacks isn't affected by Weakness or Resistance.""
# [{'name': 'Water Veil', 'text': 'Whenever you attach an Energy card from your hand to this Pokémon, remove all Special Conditions from it.', 'type': 'Ability'}]
# "[{'name': 'Red Eyes', 'text': ""When you play this Pokémon from your hand to evolve 1 of your Pokémon during your turn
# [{'name': 'Industrious Incisors', 'text': 'Once during your turn, you may draw cards until you have 5 cards in your hand.', 'type': 'Ability'}]
# [{'type': 'Ability', 'name': 'Roar of the Sword', 'text': 'Once during your turn, you may search your deck for a Psychic Energy card and attach it to 1 of your Pokémon. Then, shuffle your deck. If you use this Ability, your turn ends.'}]
# [{'name': 'Special Transfer', 'text': 'As often as you like during your turn, you may move a Special Energy from 1 of your Pokémon to another of your Pokémon.', 'type': 'Ability'}]
# "[{'name': 'Strange Behavior', 'text': ""As often as you like during your turn (before your attack)
# [{'name': 'Extreme Speed', 'text': 'You pay Colorless less to retreat Arcanine for each Energy attached to it.', 'type': 'Poké-Body'}]
# "[{'name': 'Energy Grounding', 'text': ""Once during your opponent's turn
# "[{'name': 'Buffer', 'text': ""If Jumpluff would be Knocked Out by an opponent's attack
# [{'name': 'Psychic Wing', 'text': 'If Vibrava has any Psychic Energy attached to it, the Retreat Cost for Vibrava is 0.', 'type': 'Poké-Body'}]
# "[{'name': 'Rivalry', 'text': ""If your opponent has any Pokémon LV.X in play
# "[{'name': 'Steel Coating', 'text': ""Any damage done to Probopass by your opponent's attacks is reduced by 10 for each Metal Energy attached to Probopass (after applying Weakness and Resistance). You can't reduce more than 20 damage in this way.""
# [{'name': 'Wild Dash', 'text': 'If your opponent has any Pokémon-GX or Pokémon-EX in play, this Pokémon has no Retreat Cost.', 'type': 'Ability'}]
# "[{'name': 'Ninja Body', 'text': 'Whenever your opponent plays an Item card from their hand, prevent all effects of that card done to this Pokémon.', 'type': 'Ability'}, {'name': 'Antidote Jutsu', 'text': ""This Pokémon can't be Poisoned.""
# [{'name': 'Gnawing Aura', 'text': 'As long as this Pokémon is in the Active Spot, whenever your opponent attaches an Energy card from their hand to 1 of their Pokémon, put 3 damage counters on that Pokémon.', 'type': 'Ability'}]
# "[{'name': 'Justified Law', 'text': ""Your Basic Pokémon's attacks do 30 more damage to your opponent's Active Darkness Pokémon (before applying Weakness and Resistance).""
# [{'name': 'Transformative Start', 'text': 'Once during your first turn, if this Pokémon is in the Active Spot, you may search your deck and choose a Basic Pokémon you find there, except any Ditto. If you do, discard this Pokémon and all attached cards, and put the chosen Pokémon in its place. Then, shuffle your deck.', 'type': 'Ability'}]
# [{'name': 'Magnetic Absorption', 'text': 'Once during your turn, if your opponent has 4 or fewer Prize cards remaining, you may attach a Basic Fighting Energy card from your discard pile to this Pokémon.', 'type': 'Ability'}]
# "[{'name': 'Bolt', 'text': ""Whenever your opponent's attack damages Entei
# "[{'name': 'Energy Draw', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Darkness Guard', 'text': ""As long as Rocket's Zapdos ex has any Darkness Energy attached to it
# "[{'name': 'Dragon Aura', 'text': ""As long as Rayquaza has any basic Fire Energy cards and any basic Lightning Energy cards attached to it
# [{'name': 'Stages of Evolution', 'text': 'As long as Hitmonchan is an Evolved Pokémon, Hitmonchan gets +30 HP.', 'type': 'Poké-Body'}]
# "[{'name': 'Extra Smoke', 'text': ""Any damage done to your Stage 2 Pokémon-ex by your opponent's attacks is reduced by 10 (before applying Weakness and Resistance).""
# "[{'name': 'Psychic Protector', 'text': ""If Flygon ex is damaged by an opponent's attack
# [{'name': 'Plant Cloak', 'text': 'If Wormadam Plant Cloak has 2 or more Grass Energy attached to it, Wormadam Plant Cloak gets +40 HP.', 'type': 'Poké-Body'}]
# "[{'name': 'Anger Point', 'text': ""If Primeape has any damage counters on it
# "[{'name': 'Aqua Recycle', 'text': ""Once during your turn (before your attack)
# [{'name': 'Sparkling Particles', 'text': 'At any time between turns, heal 10 damage from this Pokémon.', 'type': 'Ability'}]
# [{'name': 'Legendary Ascent', 'text': 'When you play this Pokémon from your hand onto your Bench during your turn, you may switch it with your Active Pokémon. If you do, move any number of Water Energy from your other Pokémon to this Pokémon.', 'type': 'Ability'}]
# [{'name': 'Ocean Search', 'text': 'Once during your turn, if this Pokémon is in the Active Spot, you may look at the top 6 cards of your deck, reveal a Pokémon you find there, and put it into your hand. Shuffle the other cards back into your deck.', 'type': 'Ability'}]
# "[{'name': 'Star Guardian', 'text': ""During your turn
# [{'name': 'Hard Shell', 'text': 'Whenever an attack (including your own) does 40 or less damage to Shuckle (after applying Weakness and Resistance), reduce that damage to 10. (Any other effects of attacks still happen.) This power stops working while Shuckle is Asleep, Confused, or Paralyzed.', 'type': 'Pokémon Power'}]
# "[{'name': 'Chaos Move', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Mark of Antiquity', 'text': ""As long as Groudon ex is your Active Pokémon
# [{'name': 'Eerie Aura', 'text': 'As long as Hypno is your Active Pokémon, put 2 damage counters on each Pokémon that remains Asleep between turns.', 'type': 'Poké-Body'}]
# "[{'name': 'Super Suction Cups', 'text': ""As long as Octillery is your Active Pokémon
# [{'name': 'Plasma Search', 'text': 'Once during your turn (before your attack), you may search your deck for a Team Plasma card, reveal it, and put it in your hand. Shuffle your deck afterward. You may not use an Ability with the same name during your turn.', 'type': 'Ability'}]
# "[{'name': 'Giant Fan', 'text': ""When you play this Pokémon from your hand to evolve 1 of your Pokémon
# "[{'name': 'Fainting Spell', 'text': ""If this Pokémon is Knocked Out by damage from an opponent's attack
# [{'name': 'Trade', 'text': 'You must discard a card from your hand in order to use this Ability. Once during your turn, you may draw 2 cards.', 'type': 'Ability'}]
# "[{'name': 'Lost Provisions', 'text': ""If you have 4 or more cards in the Lost Zone
# "[{'name': 'Bully of the Sands', 'text': ""When you play this Pokémon from your hand to evolve 1 of your Pokémon during your turn
# [{'name': 'Wear Cloak', 'text': 'Once during your turn (before your attack), if Burmy Sandy Cloak is your Active Pokémon, you may search your discard for a basic Fighting Energy card and attach it to Burmy Sandy Cloak.', 'type': 'Poké-Power'}]
# "[{'name': 'Snow Veil', 'text': ""As long as Abomasnow is your Active Pokémon
# "[{'name': 'Mist Concealment', 'text': ""When you play this Pokémon from your hand to evolve 1 of your Pokémon
# [{'name': 'Shadow Void', 'text': 'As often as you like during your turn (before your attack), you may move 1 damage counter from 1 of your Pokémon to this Pokémon.', 'type': 'Ability'}]
# "[{'name': 'Flaming Fighter', 'text': ""Put 6 damage counters instead of 2 on your opponent's Burned Pokémon between turns.""
# [{'name': 'Evasion Jutsu', 'text': 'If any damage is done to this Pokémon by attacks, flip a coin. If heads, prevent that damage.', 'type': 'Ability'}]
# "[{'name': 'Shadow Pain', 'text': ""When you play this Pokémon from your hand to evolve 1 of your Pokémon during your turn
# "[{'type': 'Poké-Power', 'name': 'Cosmic Power', 'text': ""Once during your turn (before your attack)
# "[{'name': 'Adverse Weather', 'text': ""As long as this Pokémon is in the Active Spot
# "[{'name': 'Photosynthesis', 'text': ""All Energy cards attached to Erika's Oddish provide Grass Energy instead of their usual type. This power works even while Erika's Oddish is Asleep
# [{'name': 'Rock Body', 'text': 'All damage done by attacks to Golem is reduced by 10 (after applying Weakness and Resistance).', 'type': 'Poké-Body'}]
# [{'name': 'Electro-guard', 'text': 'As long Minun has any Lightning Energy attached to it, Minun has no Weakness.', 'type': 'Poké-Body'}]
# [{'name': 'Baby Evolution', 'text': 'Once during your turn (before your attack), you may put Magmar from your hand onto Magby (this counts as evolving Magby) and remove all damage counters from Magby.', 'type': 'Poké-Power'}]
# "[{'name': 'Thick Skin', 'text': ""Zangoose can't be affected by any Special Conditions.""
# [{'name': 'Let Loose', 'text': 'Once during your turn, when you put Giratina from your hand onto your Bench, you may use this power. Each player shuffles his or her hand into his or her deck and draws up to 4 cards. (You draw your cards first.)', 'type': 'Poké-Power'}]
# [{'name': 'Shift Gear', 'text': 'As often as you like during your turn (before your attack), you may move a Metal Energy attached to 1 of your Pokémon to another of your Pokémon.', 'type': 'Ability'}]

# %%
pokemon_df.groupBy("generation").count().show()
# Out:
# +----------+-----+
# |generation|count|
# +----------+-----+
# |    Fourth| 1438|
# |   Seventh| 2973|
# |     First|  758|
# |    Eighth| 3665|
# |     Other|  157|
# |    Second| 1031|
# |   Fourth |  592|
# |     Ninth| 1304|
# |     Sixth| 1710|
# |     Fifth| 1653|
# |     Third| 1891|
# +----------+-----+

# %%
# Encontrar al pokemon con ma HP

from pyspark.sql.functions import desc

max_hp_pokemon = pokemon_df.select("name", "hp").orderBy(desc("hp")).limit(1)
max_hp_pokemon.show()
# Out:
# +--------------+---+
# |          name| hp|
# +--------------+---+
# |Eternatus VMAX|340|
# +--------------+---+

# %%
# Mostrar los Pokémon legendarios:

pokemon_df.select("rarity").distinct().show()
# Out:
# +--------------------+
# |              rarity|
# +--------------------+
# | put Deoxys on to...|
# |[{'name': 'Upward...|
# | {'name': 'Thunde...|
# | 'name': 'Super P...|
# | 'type': 'Pokémon...|
# |          Rare Prime|
# | {'name': 'Electr...|
# | {'name': 'Combus...|
# |[{'name': 'Chomp'...|
# |"[{'name': 'Venge...|
# | put Castform on ...|
# | 'convertedEnergy...|
# |  'cost': ['Psychic'|
# |   'cost': ['Grass']|
# | {'name': 'Brutal...|
# |"[{'name': 'Hydro...|
# | done to Seaking....|
# |[{'name': 'Poison...|
# | or anything else...|
# |['Colorless', 'Co...|
# +--------------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import col

# Explorar la columna "rarity"
pokemon_df.select("rarity").distinct().show(truncate=False)

# Filtrar Pokémon legendarios
legendary_pokemon = pokemon_df.filter(
    (col("rarity").like("%Legend%")) |
    (col("rarity").like("%Rare Prime%")) |
    (col("rarity").like("%EX%"))  # Puedes agregar más condiciones según las rarezas de tus Pokémon legendarios
)

legendary_pokemon.select("id", "name", "rarity").show(truncate=False)
# Out:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |rarity                                                                                                                                                                                                                                                                                                                                                                                |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | put Deoxys on top of your deck. Shuffle your deck afterward. You can't use more than 1 Form Change Poké-Power each turn.""                                                                                                                                                                                                                                                           |
# |[{'name': 'Upward Kick', 'cost': ['Fighting', 'Colorless'], 'convertedEnergyCost': 2, 'damage': '20+', 'text': 'If the Defending Pokémon already has at least 2 damage counters on it, this attack does 20 damage plus 30 more damage.'}, {'name': 'Spiral Kick', 'cost': ['Colorless', 'Colorless', 'Colorless', 'Colorless'], 'convertedEnergyCost': 4, 'damage': '50', 'text': ''}]|
# | {'name': 'Thunderbolt'                                                                                                                                                                                                                                                                                                                                                               |
# | 'name': 'Super Psy Bolt'                                                                                                                                                                                                                                                                                                                                                             |
# | 'type': 'Pokémon Power'}]"                                                                                                                                                                                                                                                                                                                                                           |
# |Rare Prime                                                                                                                                                                                                                                                                                                                                                                            |
# | {'name': 'Electro Ball'                                                                                                                                                                                                                                                                                                                                                              |
# | {'name': 'Combustion'                                                                                                                                                                                                                                                                                                                                                                |
# |[{'name': 'Chomp', 'cost': ['Water', 'Water', 'Water', 'Water'], 'convertedEnergyCost': 4, 'damage': '50+', 'text': 'Flip a number of coins equal to the number of damage counters on Feraligatr. This attack does 50 damage plus 10 more damage for each heads.'}]                                                                                                                   |
# |"[{'name': 'Vengeance', 'cost': ['Colorless', 'Colorless', 'Colorless'], 'convertedEnergyCost': 3, 'damage': '30+', 'text': ""Does 30 damage plus 10 more damage for each Basic Pokémon and each Evolution card in your discard pile. You can't add more than 60 damage in this way.""}]"                                                                                             |
# | put Castform on top of your deck. Shuffle your deck afterward. You can't use more than 1 Temperament Poké-Power each turn.""                                                                                                                                                                                                                                                         |
# | 'convertedEnergyCost': 0                                                                                                                                                                                                                                                                                                                                                             |
# | 'cost': ['Psychic'                                                                                                                                                                                                                                                                                                                                                                   |
# | 'cost': ['Grass']                                                                                                                                                                                                                                                                                                                                                                    |
# | {'name': 'Brutal Edge'                                                                                                                                                                                                                                                                                                                                                               |
# |"[{'name': 'Hydro Pump', 'cost': ['Water', 'Water', 'Water'], 'convertedEnergyCost': 3, 'damage': '40+', 'text': ""Does 40 damage plus 10 more damage for each Water Energy attached to Blastoise but not used to pay for this attack's Energy cost. You can't add more than 20 damage in this way.""}]"                                                                              |
# | done to Seaking.""}]"                                                                                                                                                                                                                                                                                                                                                                |
# |[{'name': 'Poison Thread', 'cost': ['Grass'], 'convertedEnergyCost': 1, 'damage': '', 'text': 'The Defending Pokémon is now Poisoned.'}]                                                                                                                                                                                                                                              |
# | or anything else that might be the result of an attack (just as if you had evolved it).""}]"                                                                                                                                                                                                                                                                                         |
# |['Colorless', 'Colorless', 'Colorless', 'Colorless']                                                                                                                                                                                                                                                                                                                                  |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows
#
# +-------+-------------+------------+
# |id     |name         |rarity      |
# +-------+-------------+------------+
# |ex1-96 |Chansey ex   |Rare Holo EX|
# |ex1-97 |Electabuzz ex|Rare Holo EX|
# |ex1-98 |Hitmonchan ex|Rare Holo EX|
# |ex1-101|Mewtwo ex    |Rare Holo EX|
# |ex1-103|Sneasel ex   |Rare Holo EX|
# |ex2-95 |Aggron ex    |Rare Holo EX|
# |ex2-98 |Raichu ex    |Rare Holo EX|
# |ex3-93 |Latias ex    |Rare Holo EX|
# |ex3-94 |Latios ex    |Rare Holo EX|
# |ex3-95 |Magcargo ex  |Rare Holo EX|
# |ex3-96 |Muk ex       |Rare Holo EX|
# |ex3-97 |Rayquaza ex  |Rare Holo EX|
# |ex4-89 |Blaziken ex  |Rare Holo EX|
# |ex4-91 |Entei ex     |Rare Holo EX|
# |ex4-92 |Raikou ex    |Rare Holo EX|
# |ex5-98 |Regirock ex  |Rare Holo EX|
# |ex5-99 |Registeel ex |Rare Holo EX|
# |ex5-101|Wigglytuff ex|Rare Holo EX|
# |ex6-109|Gyarados ex  |Rare Holo EX|
# |ex8-102|Rayquaza ex  |Rare Holo EX|
# +-------+-------------+------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import ArrayType, StringType

# Función para extraer nombres de ataques y habilidades
def extract_names(rarity):
    # Utilizar expresiones regulares para extraer nombres de ataques
    attack_names = re.findall(r"'name':\s*'([^']+)'|"r'"name":\s*"([^"]+)"', str(rarity))

    # Utilizar expresiones regulares para extraer nombres de habilidades
    ability_names = re.findall(r"'abilities':\s*\[.*?{'name':\s*'([^']+)'|"r"'abilities':\s*\[.*?\"name\":\s*\"([^']+)'", str(rarity))

    # Filtrar elementos no vacíos y combinar las listas
    attack_names = [name for name in sum(attack_names, ()) if name]
    ability_names = [name for name in sum(ability_names, ()) if name]

    return attack_names, ability_names

# Registro de la función UDF
extract_names_udf = udf(extract_names, ArrayType(StringType()))

# Convertir la columna "rarity" a tipo de datos String
pokemon_df = pokemon_df.withColumn("rarity", pokemon_df["rarity"].cast(StringType()))

# Aplicar la función UDF a la columna "rarity" para extraer nombres de ataques y habilidades
pokemon_df_with_names = pokemon_df.withColumn("names", extract_names_udf("rarity"))

# Dividir el resultado en columnas separadas para ataques y habilidades
pokemon_df_with_attacks = pokemon_df_with_names.withColumn("attack_names", pokemon_df_with_names["names"].getItem(0))
pokemon_df_with_abilities = pokemon_df_with_attacks.withColumn("ability_names", pokemon_df_with_names["names"].getItem(1))

# Mostrar el resultado
pokemon_df_with_abilities.select("id", "name", "attack_names", "ability_names").show(truncate=False)
# Out:
# +--------+----------+--------------+-------------+
# |id      |name      |attack_names  |ability_names|
# +--------+----------+--------------+-------------+
# |base1-1 |Alakazam  |[Confuse Ray] |[]           |
# |base1-2 |Blastoise |[Hydro Pump]  |[]           |
# |base1-3 |Chansey   |[]            |[]           |
# |base1-4 |Charizard |[Fire Spin]   |[]           |
# |base1-5 |Clefairy  |[]            |[]           |
# |base1-6 |Gyarados  |[]            |[]           |
# |base1-7 |Hitmonchan|[]            |[]           |
# |base1-8 |Machamp   |[Seismic Toss]|[]           |
# |base1-9 |Magneton  |[]            |[]           |
# |base1-10|Mewtwo    |[]            |[]           |
# |base1-11|Nidoking  |[]            |[]           |
# |base1-12|Ninetales |[]            |[]           |
# |base1-13|Poliwrath |[]            |[]           |
# |base1-14|Raichu    |[]            |[]           |
# |base1-15|Venusaur  |[Solarbeam]   |[]           |
# |base1-16|Zapdos    |[]            |[]           |
# |base1-17|Beedrill  |[]            |[]           |
# |base1-18|Dragonair |[]            |[]           |
# |base1-19|Dugtrio   |[]            |[]           |
# |base1-20|Electabuzz|[]            |[]           |
# +--------+----------+--------------+-------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import ArrayType, StringType

# Función para extraer nombres de ataques y habilidades
def extract_names(rarity):
    # Utilizar expresiones regulares para extraer nombres de ataques
    attack_names = re.findall(r"'name':\s*'([^']+)'|"r'"name":\s*"([^"]+)"', str(rarity))

    # Utilizar expresiones regulares para extraer nombres de habilidades
    ability_names = re.findall(r"'abilities':\s*\[.*?{'name':\s*'([^']+)'|"r"'abilities':\s*\[.*?\"name\":\s*\"([^']+)'", str(rarity))

    # Filtrar elementos no vacíos y combinar las listas
    attack_names = [name for name in sum(attack_names, ()) if name]
    ability_names = [name for name in sum(ability_names, ()) if name]

    return attack_names, ability_names

# Registro de la función UDF
extract_names_udf = udf(extract_names, ArrayType(StringType()))

# Aplicar la función UDF a la columna "rarity" para extraer nombres de ataques y habilidades
pokemon_df_with_names = pokemon_df.withColumn("names", extract_names_udf("rarity"))

# Dividir el resultado en columnas separadas para ataques y habilidades
pokemon_df_with_attacks = pokemon_df_with_names.withColumn("attack_names", pokemon_df_with_names["names"].getItem(0))
pokemon_df_with_abilities = pokemon_df_with_attacks.withColumn("ability_names", pokemon_df_with_names["names"].getItem(1))

# Mostrar el resultado
pokemon_df_with_abilities.select("id", "name", "attack_names", "ability_names").show(truncate=False)
# Out:
# +--------+----------+--------------+-------------+
# |id      |name      |attack_names  |ability_names|
# +--------+----------+--------------+-------------+
# |base1-1 |Alakazam  |[Confuse Ray] |[]           |
# |base1-2 |Blastoise |[Hydro Pump]  |[]           |
# |base1-3 |Chansey   |[]            |[]           |
# |base1-4 |Charizard |[Fire Spin]   |[]           |
# |base1-5 |Clefairy  |[]            |[]           |
# |base1-6 |Gyarados  |[]            |[]           |
# |base1-7 |Hitmonchan|[]            |[]           |
# |base1-8 |Machamp   |[Seismic Toss]|[]           |
# |base1-9 |Magneton  |[]            |[]           |
# |base1-10|Mewtwo    |[]            |[]           |
# |base1-11|Nidoking  |[]            |[]           |
# |base1-12|Ninetales |[]            |[]           |
# |base1-13|Poliwrath |[]            |[]           |
# |base1-14|Raichu    |[]            |[]           |
# |base1-15|Venusaur  |[Solarbeam]   |[]           |
# |base1-16|Zapdos    |[]            |[]           |
# |base1-17|Beedrill  |[]            |[]           |
# |base1-18|Dragonair |[]            |[]           |
# |base1-19|Dugtrio   |[]            |[]           |
# |base1-20|Electabuzz|[]            |[]           |
# +--------+----------+--------------+-------------+
# only showing top 20 rows

# %%
# Extracción de información descriptiva
descriptive_info = pokemon_df.filter("rarity NOT LIKE '%name%'")  # Filtrar las filas que no contienen "name"
descriptive_info.select("id", "name", "rarity").show(truncate=False)
# Out:
# +--------+----------+---------------------------------------+
# |id      |name      |rarity                                 |
# +--------+----------+---------------------------------------+
# |base1-3 |Chansey   | 'Colorless'                           |
# |base1-5 |Clefairy  |['Colorless']                          |
# |base1-6 |Gyarados  |Rare Holo                              |
# |base1-7 |Hitmonchan|Rare Holo                              |
# |base1-9 |Magneton  |Rare Holo                              |
# |base1-10|Mewtwo    |['Colorless', 'Colorless', 'Colorless']|
# |base1-11|Nidoking  |Rare Holo                              |
# |base1-12|Ninetales |Rare Holo                              |
# |base1-13|Poliwrath | 'Colorless'                           |
# |base1-14|Raichu    | done to Raichu.""}                    |
# |base1-16|Zapdos    |Rare Holo                              |
# |base1-17|Beedrill  |Rare                                   |
# |base1-18|Dragonair |Rare                                   |
# |base1-19|Dugtrio   |Rare                                   |
# |base1-20|Electabuzz|Rare                                   |
# |base1-21|Electrode | 'type': 'Pokémon Power'}]"            |
# |base1-22|Pidgeotto |Rare                                   |
# |base1-23|Arcanine  |Uncommon                               |
# |base1-24|Charmeleon|Uncommon                               |
# |base1-25|Dewgong   |Uncommon                               |
# +--------+----------+---------------------------------------+
# only showing top 20 rows

# %%
# Pokémon más común en la base de datos:
common_pokemon = pokemon_df.groupBy("name").count().orderBy("count", ascending=False)
common_pokemon.show()
# Out:
# +----------+-----+
# |      name|count|
# +----------+-----+
# |   Pikachu|   98|
# |     Eevee|   58|
# | Magnemite|   41|
# |    Raichu|   41|
# |Charmander|   38|
# |     Unown|   36|
# |   Snorlax|   35|
# |  Magneton|   35|
# |  Magikarp|   34|
# |   Voltorb|   32|
# | Electrode|   31|
# | Growlithe|   31|
# |    Meowth|   31|
# |    Lapras|   30|
# |    Vulpix|   30|
# | Ninetales|   29|
# |   Torchic|   28|
# |  Gyarados|   28|
# |  Arcanine|   28|
# |   Lucario|   27|
# +----------+-----+
# only showing top 20 rows

# %%
# Número total de Pokémon por generación: CARTAS DE POKEMON
pokemon_per_generation = pokemon_df.groupBy("generation").count().orderBy("generation")
pokemon_per_generation.show()
# Out:
# +----------+-----+
# |generation|count|
# +----------+-----+
# |    Eighth| 3665|
# |     Fifth| 1653|
# |     First|  758|
# |    Fourth| 1438|
# |   Fourth |  592|
# |     Ninth| 1304|
# |     Other|  157|
# |    Second| 1031|
# |   Seventh| 2973|
# |     Sixth| 1710|
# |     Third| 1891|
# +----------+-----+

# %%
# Promedio de puntos de salud (HP) por generación:CARTAS
average_hp_per_generation = pokemon_df.groupBy("generation").agg({"hp": "avg"}).orderBy("generation")
average_hp_per_generation.show()
# Out:
# +----------+------------------+
# |generation|           avg(hp)|
# +----------+------------------+
# |    Eighth| 142.0730503455084|
# |     Fifth| 98.01078894133514|
# |     First| 60.53872053872054|
# |    Fourth| 81.34270101483216|
# |   Fourth | 75.82857142857142|
# |     Ninth|124.28317008014247|
# |     Other| 68.40764331210191|
# |    Second| 65.22928490351873|
# |   Seventh|122.35749185667753|
# |     Sixth|104.58333333333333|
# |     Third| 70.38006230529595|
# +----------+------------------+
